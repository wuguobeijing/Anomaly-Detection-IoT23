# %%
import autogluon.core as ag

nn_options = {  # specifies non-default hyperparameter values for neural network models
    'num_epochs': 50,
        'learning_rate': ag.space.Real(1e-4, 3e-2, default=3e-4, log=True),
        'weight_decay': ag.space.Real(1e-12, 0.1, default=1e-6, log=True),
        'dropout_prob': ag.space.Categorical(0.1, 0.0, 0.5, 0.2, 0.3, 0.4),
        'embedding_size_factor': ag.space.Categorical(1.0, 0.5, 1.5, 0.7, 0.6, 0.8, 0.9, 1.1, 1.2, 1.3, 1.4),
        'proc.embed_min_categories': ag.space.Categorical(4, 3, 10, 100, 1000),
        'proc.impute_strategy': ag.space.Categorical('median', 'mean', 'most_frequent'),
        'proc.max_category_levels': ag.space.Categorical(100, 10, 20, 200, 300, 400, 500, 1000, 10000),
        'proc.skew_threshold': ag.space.Categorical(0.99, 0.2, 0.3, 0.5, 0.8, 0.9, 0.999, 1.0, 10.0, 100.0),
        'num_layers': ag.space.Categorical(2, 3, 4),
        'hidden_size': ag.space.Categorical(128, 256, 512),
        'activation': ag.space.Categorical('relu', 'elu'),
    'use_batchnorm':True
}
nn_option_best = {}
CAT_options = {
    'learning_rate': ag.space.Real(lower=5e-3, upper=0.2, default=0.05, log=True),
        'depth': ag.space.Int(lower=5, upper=8, default=6),
        'l2_leaf_reg': ag.space.Real(lower=1, upper=5, default=3),
}
CAT_option_best ={}

gbm_options = {  # specifies non-default hyperparameter values for lightGBM gradient boosted trees
    'num_boost_round': 10,  # number of boosting rounds (controls training time of GBM models)
    'num_leaves': ag.space.Int(lower=6, upper=36, default=16),  # number of leaves in trees (integer hyperparameter)
            'learning_rate': ag.space.Real(lower=5e-3, upper=0.2, default=0.05, log=True),
        'feature_fraction': ag.space.Real(lower=0.75, upper=1.0, default=1.0),
        'min_data_in_leaf': ag.space.Int(lower=2, upper=60, default=20),  # TODO: Use size of dataset to set upper, if row count is small upper should be small
}
gbm_option_best ={}
XGB_option_best = {}

XGB_option ={
            'learning_rate': ag.space.Real(lower=5e-3, upper=0.2, default=0.1, log=True),
        'max_depth': ag.space.Int(lower=3, upper=10, default=6),
        'min_child_weight': ag.space.Int(lower=1, upper=5, default=1),
        'gamma': ag.space.Real(lower=0, upper=5, default=0.01),
        'subsample': ag.space.Real(lower=0.5, upper=1.0, default=1.0),
        'colsample_bytree': ag.space.Real(lower=0.5, upper=1.0, default=1.0),
        'reg_alpha': ag.space.Real(lower=0.0, upper=10.0, default=0.0),
        'reg_lambda': ag.space.Real(lower=0.0, upper=10.0, default=1.0),
}

XT_options = {}
RF_option = {}
FASTAI_options = {
            # 'layers': ag.space.Categorical(None, [200, 100], [200], [500],  [500, 200], [50, 25], [200, 100, 50], [500, 200, 100]),
        'emb_drop': ag.space.Real(0.0, 0.5, default=0.2),
        'ps': ag.space.Real(0.0, 0.5, default=0.1),
        'bs': ag.space.Categorical(256, 64, 128, 512, 1024, 2048, 4096),
        'lr': ag.space.Real(5e-5, 1e-1, default=1e-3, log=True),
}
hyperparameters = {  # hyperparameters of each model type
    # 'XGB': XGB_option_best
    # 'RF':RF_option,
    # 'XT' : XT_options,
    'GBM': gbm_options,
    #  'CAT' : CAT_option_best,
    # 'NN_TORCH': nn_options,  # NOTE: comment this line out if you get errors on Mac OSX

}  # When these keys are missing from hyperparameters dict, no models of that type are trained

time_limit = 6 * 60  # train various models for ~2 min
num_trials = 5  # try at most 5 different hyperparameter configurations for each type of model
search_strategy = 'auto'  # to tune hyperparameters using random search routine with a local scheduler

hyperparameter_tune_kwargs = {  # HPO is not performed unless hyperparameter_tune_kwargs is specified
    'num_trials': num_trials,
    'scheduler': 'local',
    'searcher': search_strategy,
}

# %%
from autogluon.tabular import TabularPredictor, TabularDataset

train_data = TabularDataset("/media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/Data/self_data1.csv")
save_path = '/media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2'
label = 'label'
# print(predictor_tune.fit_summary())
predictor = TabularPredictor(label=label, eval_metric='roc_auc',path=save_path).fit(
    train_data, num_bag_folds=5, num_bag_sets=1, num_stack_levels=0,
    time_limit=time_limit, presets='optimize_for_deployment', hyperparameters=hyperparameters,
    hyperparameter_tune_kwargs=hyperparameter_tune_kwargs, verbosity=4,
    ag_args_fit={'num_gpus': 1},
)
# Out:
# Presets specified: ['optimize_for_deployment']
# ============ fit kwarg info ============
# User Specified kwargs:
# {'ag_args_fit': {'num_gpus': 1},
#  'hyperparameter_tune_kwargs': {'num_trials': 5,
#                                 'scheduler': 'local',
#                                 'searcher': 'auto'},
#  'keep_only_best': True,
#  'num_bag_folds': 5,
#  'num_bag_sets': 1,
#  'num_stack_levels': 0,
#  'save_space': True,
#  'verbosity': 4}
# Full kwargs:
# {'_feature_generator_kwargs': None,
#  '_save_bag_folds': None,
#  'ag_args': None,
#  'ag_args_ensemble': None,
#  'ag_args_fit': {'num_gpus': 1},
#  'auto_stack': False,
#  'calibrate': 'auto',
#  'excluded_model_types': None,
#  'feature_generator': 'auto',
#  'feature_prune_kwargs': None,
#  'holdout_frac': None,
#  'hyperparameter_tune_kwargs': {'num_trials': 5,
#                                 'scheduler': 'local',
#                                 'searcher': 'auto'},
#  'keep_only_best': True,
#  'name_suffix': None,
#  'num_bag_folds': 5,
#  'num_bag_sets': 1,
#  'num_stack_levels': 0,
#  'pseudo_data': None,
#  'quantile_levels': None,
#  'refit_full': False,
#  'save_space': True,
#  'set_best_to_refit_full': False,
#  'unlabeled_data': None,
#  'use_bag_holdout': False,
#  'verbosity': 4}
# ========================================
# Warning: hyperparameter tuning is currently experimental and may cause the process to hang.
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/learner.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/predictor.pkl
# Beginning AutoGluon training ... Time limit = 360s
# AutoGluon will save models to "/media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/"
# AutoGluon Version:  0.4.0
# Python Version:     3.8.13
# Operating System:   Linux
# Train Data Rows:    3002
# Train Data Columns: 29
# Label Column: label
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['malicious', 'normal']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = normal, class 0 = malicious
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (normal) vs negative (malicious) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10749.44 MB
# 	Train Data (Original)  Memory Usage: 0.7 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 18 features to boolean dtype as they only contain 2 unique values.
# 			Original Features (exact raw dtype, raw dtype):
# 				('float64', 'float') :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int64', 'int')     : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			Types of features in original data (raw dtype, special dtypes):
# 				('float', []) :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int', [])   : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			Types of features in processed data (exact raw dtype, raw dtype):
# 				('float64', 'float') :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int8', 'int')      : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			Types of features in processed data (raw dtype, special dtypes):
# 				('float', [])     :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int', ['bool']) : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			0.0s = Fit runtime
# 			23 features in original data used to generate 23 features in processed data.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 			Types of features in original data (raw dtype, special dtypes):
# 				('float', [])     :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int', ['bool']) : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			Types of features in processed data (exact raw dtype, raw dtype):
# 				('float64', 'float') :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int8', 'int')      : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			Types of features in processed data (raw dtype, special dtypes):
# 				('float', [])     :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int', ['bool']) : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			0.0s = Fit runtime
# 			23 features in original data used to generate 23 features in processed data.
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 			Types of features in original data (raw dtype, special dtypes):
# 				('float', [])     :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int', ['bool']) : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			Types of features in processed data (exact raw dtype, raw dtype):
# 				('float64', 'float') :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int8', 'int')      : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			Types of features in processed data (raw dtype, special dtypes):
# 				('float', [])     :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int', ['bool']) : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			0.0s = Fit runtime
# 			23 features in original data used to generate 23 features in processed data.
# 		Skipping CategoryFeatureGenerator: No input feature with required dtypes.
# 		Skipping DatetimeFeatureGenerator: No input feature with required dtypes.
# 		Skipping TextSpecialFeatureGenerator: No input feature with required dtypes.
# 		Skipping TextNgramFeatureGenerator: No input feature with required dtypes.
# 		Skipping IdentityFeatureGenerator: No input feature with required dtypes.
# 		Skipping IsNanFeatureGenerator: No input feature with required dtypes.
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 			Types of features in original data (raw dtype, special dtypes):
# 				('float', [])     :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int', ['bool']) : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			Types of features in processed data (exact raw dtype, raw dtype):
# 				('float64', 'float') :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int8', 'int')      : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			Types of features in processed data (raw dtype, special dtypes):
# 				('float', [])     :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 				('int', ['bool']) : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 			0.0s = Fit runtime
# 			23 features in original data used to generate 23 features in processed data.
# 	Useless Original Features (Count: 6): ['proto_ARP', 'origstate_', 'appproto_', 'proto_unknown', 'origstate_unknown', 'appproto_unknown']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (exact raw dtype, raw dtype):
# 		('float64', 'float') :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 		('int64', 'int')     : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 		('int', [])   : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 	Types of features in processed data (exact raw dtype, raw dtype):
# 		('float64', 'float') :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 		('int8', 'int')      : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# 		('int', ['bool']) : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# 	0.1s = Fit runtime
# 	23 features in original data used to generate 23 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.17 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.07s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/learner.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/utils/data/X.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/utils/data/y.pkl
# Model configs that will be trained (in order):
# 	LightGBM_BAG_L1: 	{'num_boost_round': 10, 'num_leaves': Int: lower=6, upper=36, 'learning_rate': Real: lower=0.005, upper=0.2, 'feature_fraction': Real: lower=0.75, upper=1.0, 'min_data_in_leaf': Int: lower=2, upper=60, 'ag_args': {'hyperparameter_tune_kwargs': {'num_trials': 5, 'scheduler': 'local', 'searcher': 'auto'}, 'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 90}, 'ag_args_fit': {'num_gpus': 1}}
# Fitting 1 L1 models ...
# Hyperparameter tuning model: LightGBM_BAG_L1 ... Tuning model for up to 64.79s of the 359.93s of remaining time.
# 	Dropped 0 of 23 features.
# 	Dropped 0 of 23 features.
# 	Dropped 0 of 23 features.
# Starting generic AbstractModel hyperparameter tuning for LightGBM model...
# 	Hyperparameter search space for LightGBM:
# learning_rate:   Real: lower=0.005, upper=0.2
# num_leaves:   Int: lower=6, upper=36
# feature_fraction:   Real: lower=0.75, upper=1.0
# min_data_in_leaf:   Int: lower=2, upper=60
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_train.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_val.pkl
#   0%|          | 0/5 [00:00<?, ?it/s]
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_train.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_val.pkl
# 	Dropped 0 of 23 features.
# 	Fitting LightGBM/T1 with 'num_gpus': 1, 'num_cpus': 8
# 	Training LightGBM/T1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Fitting 10 rounds... Hyperparameters: {'learning_rate': 0.05, 'num_leaves': 16, 'feature_fraction': 1.0, 'min_data_in_leaf': 20, 'device': 'gpu'}
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/LightGBM/T1/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_train.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_val.pkl
# 	Dropped 0 of 23 features.
# 	Fitting LightGBM/T2 with 'num_gpus': 1, 'num_cpus': 8
# 	Training LightGBM/T2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Fitting 10 rounds... Hyperparameters: {'learning_rate': 0.06994332504138305, 'num_leaves': 33, 'feature_fraction': 0.8872033759818312, 'min_data_in_leaf': 5, 'device': 'gpu'}
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/LightGBM/T2/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_train.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_val.pkl
# 	Dropped 0 of 23 features.
# 	Fitting LightGBM/T3 with 'num_gpus': 1, 'num_cpus': 8
# 	Training LightGBM/T3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Fitting 10 rounds... Hyperparameters: {'learning_rate': 0.023861097124304616, 'num_leaves': 24, 'feature_fraction': 0.8862207957492242, 'min_data_in_leaf': 23, 'device': 'gpu'}
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/LightGBM/T3/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_train.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_val.pkl
# 	Dropped 0 of 23 features.
# 	Fitting LightGBM/T4 with 'num_gpus': 1, 'num_cpus': 8
# 	Training LightGBM/T4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Fitting 10 rounds... Hyperparameters: {'learning_rate': 0.13416642577896967, 'num_leaves': 18, 'feature_fraction': 0.8593968028156731, 'min_data_in_leaf': 26, 'device': 'gpu'}
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/LightGBM/T4/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_train.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/dataset_val.pkl
# 	Dropped 0 of 23 features.
# 	Fitting LightGBM/T5 with 'num_gpus': 1, 'num_cpus': 8
# 	Training LightGBM/T5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Fitting 10 rounds... Hyperparameters: {'learning_rate': 0.09276005809908326, 'num_leaves': 20, 'feature_fraction': 0.8458603797064445, 'min_data_in_leaf': 25, 'device': 'gpu'}
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/LightGBM/T5/model.pkl
# Time for LightGBM model HPO: 5.9974024295806885
# Best hyperparameter configuration for LightGBM model:
# {'learning_rate': 0.05, 'num_boost_round': 10, 'num_leaves': 16, 'feature_fraction': 1.0, 'min_data_in_leaf': 20}
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/LightGBM/T1/model.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/utils/model_template.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/LightGBM/T2/model.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/utils/model_template.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/LightGBM/T3/model.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/utils/model_template.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/LightGBM/T4/model.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/utils/model_template.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/hpo/LightGBM/T5/model.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/utils/model_template.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/model.pkl
# Fitted model: LightGBM_BAG_L1/T1 ...
# 	0.988	 = Validation score   (roc_auc)
# 	4.93s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/model.pkl
# Fitted model: LightGBM_BAG_L1/T2 ...
# 	0.988	 = Validation score   (roc_auc)
# 	0.19s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/model.pkl
# Fitted model: LightGBM_BAG_L1/T3 ...
# 	0.9879	 = Validation score   (roc_auc)
# 	0.18s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/model.pkl
# Fitted model: LightGBM_BAG_L1/T4 ...
# 	0.9879	 = Validation score   (roc_auc)
# 	0.15s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/model.pkl
# Fitted model: LightGBM_BAG_L1/T5 ...
# 	0.9879	 = Validation score   (roc_auc)
# 	0.15s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/model.pkl
# Fitting model: LightGBM_BAG_L1/T1 ... Training model for up to 353.76s of the 353.76s of remaining time.
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/utils/model_template.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/utils/oof.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/utils/model_template.pkl
# 	Dropped 0 of 23 features.
# 	Fitting 4 child models (S1F2 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/model.pkl
# 	0.9846	 = Validation score   (roc_auc)
# 	6.18s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/model.pkl
# Fitting model: LightGBM_BAG_L1/T2 ... Training model for up to 337.43s of the 337.43s of remaining time.
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/utils/model_template.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/utils/oof.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/utils/model_template.pkl
# 	Dropped 0 of 23 features.
# 	Fitting 4 child models (S1F2 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/model.pkl
# 	0.9873	 = Validation score   (roc_auc)
# 	1.11s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/model.pkl
# Fitting model: LightGBM_BAG_L1/T3 ... Training model for up to 335.95s of the 335.95s of remaining time.
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/utils/model_template.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/utils/oof.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/utils/model_template.pkl
# 	Dropped 0 of 23 features.
# 	Fitting 4 child models (S1F2 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/model.pkl
# 	0.9865	 = Validation score   (roc_auc)
# 	1.09s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/model.pkl
# Fitting model: LightGBM_BAG_L1/T4 ... Training model for up to 334.36s of the 334.36s of remaining time.
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/utils/model_template.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/utils/oof.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/utils/model_template.pkl
# 	Dropped 0 of 23 features.
# 	Fitting 4 child models (S1F2 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/model.pkl
# 	0.9865	 = Validation score   (roc_auc)
# 	1.0s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/model.pkl
# Fitting model: LightGBM_BAG_L1/T5 ... Training model for up to 332.93s of the 332.93s of remaining time.
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/utils/model_template.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/utils/oof.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/utils/model_template.pkl
# 	Dropped 0 of 23 features.
# 	Fitting 4 child models (S1F2 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/model.pkl
# 	0.9864	 = Validation score   (roc_auc)
# 	0.98s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/utils/oof.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/utils/oof.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/utils/oof.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/utils/oof.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/utils/oof.pkl
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 359.93s of the 328.95s of remaining time.
# 	Dropped 0 of 5 features.
# 	Dropped 0 of 5 features.
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/WeightedEnsemble_L2/utils/model_template.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/WeightedEnsemble_L2/utils/model_template.pkl
# 	Dropped 0 of 5 features.
# 	Fitting S1F1 with 'num_gpus': 0, 'num_cpus': 16
# Ensemble size: 1
# Ensemble indices: [1]
# Ensemble weights:
# [0. 1. 0. 0. 0.]
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/WeightedEnsemble_L2/utils/oof.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/WeightedEnsemble_L2/model.pkl
# 	0.9873	 = Validation score   (roc_auc)
# 	0.51s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# AutoGluon training complete, total runtime = 31.57s ... Best model: "WeightedEnsemble_L2"
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/model.pkl
# Deleting model LightGBM_BAG_L1/T1. All files under /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T1/ will be removed.
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/model.pkl
# Deleting model LightGBM_BAG_L1/T3. All files under /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T3/ will be removed.
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/model.pkl
# Deleting model LightGBM_BAG_L1/T4. All files under /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T4/ will be removed.
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/model.pkl
# Deleting model LightGBM_BAG_L1/T5. All files under /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T5/ will be removed.
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/model.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/WeightedEnsemble_L2/model.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/WeightedEnsemble_L2/model.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/learner.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/predictor.pkl
# Saving /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/__version__ with contents "0.4.0"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/")

# %%
predictor.fit_summary()
predictor_tune = TabularPredictor.load(save_path)
perf = predictor_tune.evaluate(train_data, auxiliary_metrics=True)
print(perf)
# Out:
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/WeightedEnsemble_L2/model.pkl
# /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Machine_learning_venv/lib/python3.8/site-packages/autogluon/core/utils/plots.py:138: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/predictor.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/learner.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/trainer.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/WeightedEnsemble_L2/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/model.pkl
# *** Summary of fit() ***
# Estimated performance of each model:
#                  model  score_val  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   LightGBM_BAG_L1/T2   0.987307       0.041295  1.106241                0.041295           1.106241            1       True          1
# 1  WeightedEnsemble_L2   0.987307       0.042869  1.612065                0.001574           0.505824            2       True          2
# Number of models trained: 2
# Types of models trained:
# {'WeightedEnsembleModel', 'StackerEnsembleModel_LGB'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     :  5 | ['dur', 'pkts', 'allbytes', 'spkts', 'sbytes']
# ('int', ['bool']) : 18 | ['proto_icmp', 'proto_tcp', 'proto_udp', 'origstate_OTH', 'origstate_REJ', ...]
# *** End of fit() summary ***
# Evaluation: roc_auc on test data: 0.9890679958330693
# Evaluations on test data:
# {
#     "roc_auc": 0.9890679958330693,
#     "accuracy": 0.9823451032644903,
#     "balanced_accuracy": 0.9739685658153241,
#     "mcc": 0.9608710020343108,
#     "f1": 0.97327281896117,
#     "precision": 1.0,
#     "recall": 0.9479371316306483
# }
# {'roc_auc': 0.9890679958330693, 'accuracy': 0.9823451032644903, 'balanced_accuracy': 0.9739685658153241, 'mcc': 0.9608710020343108, 'f1': 0.97327281896117, 'precision': 1.0, 'recall': 0.9479371316306483}

# %%
import time
t0 = time.time()
predictor.predict(train_data)
t1 = time.time()
# print(t0,t1)
# perf = predictor_tune.evaluate(test_data, auxiliary_metrics=True)
# print(perf)
(t1-t0)/3002
# Out:
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/WeightedEnsemble_L2/model.pkl
# Loading: /media/wuguo-buaa/LENOVO_USB_HDD/PycharmProjects/Anomaly-Detection-IoT23/Models/auto_gl/self_data_model/exp_gbm_2/models/LightGBM_BAG_L1/T2/model.pkl
# 2.5527783825268832e-05
